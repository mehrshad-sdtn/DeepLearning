# %% [markdown]
# <a href="https://colab.research.google.com/github/mehrshad-sdtn/DeepLearning/blob/master/NeuralNets/NN/Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from sklearn.datasets import make_moons

# %%
X, y = make_moons(n_samples=3000, noise=0.1, random_state=42)
y_true = np.expand_dims(y, axis=-1)

plt.scatter(X[:, 0], X[:, 1], c=y)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Moon Dataset')
plt.show()

# %%
def training_loop(X, y, loss_fn, lr= 0.001, epochs=100):
  m = X.shape[0]
  for i in range(0, epochs):
    y_pred = nn.forward(X)
    loss = loss_fn(y, y_pred)
    cost = np.sum(loss) / m
    print(cost)
    dw = np.dot(X.T, y_pred - y) / m
    db = np.sum(y_pred - y) / m
    nn.weights -= lr * dw
    nn.bias -= lr * db


def evaluate(X, y):
  probs = np.squeeze(nn.forward(X))
  preds = (probs >= 0.5).astype(int)
  correct = 0
  for pred, y in zip(preds, y):
    if pred == y: correct += 1
  print("accuracy: ", (correct / X.shape[0]) * 100)

# %%
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def logistic_loss(y, y_hat):
    return -(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat))

# %%
class Neuron():
  def __init__(self, ins, activation):
    self.inputs_c = ins
    self.activation = activation
    self.weights = np.random.randn(self.inputs_c, 1)
    self.bias = 0

  def __repr__(self):
    return f"Node({self.inputs_c}, {self.activation})"

  def forward(self, x):
    z = np.dot(x, self.weights) + self.bias
    y_pred = self.activation(z)
    return y_pred

# %%
nn = Neuron(2, sigmoid)

# %%
evaluate(X, y_true)
# Out:
# accuracy:  63.66666666666667

# %%
training_loop(X, y_true, logistic_loss, lr= 0.001, epochs=50000)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.314038211898063
# 0.31403645883304887
# 0.3140347058352185
# 0.3140329529045685
# 0.31403120004109575
# 0.3140294472447969
# 0.3140276945156687
# 0.3140259418537078
# 0.3140241892589109
# 0.3140224367312749
# 0.31402068427079627
# 0.314018931877472
# 0.31401717955129854
# 0.3140154272922728
# 0.3140136751003914
# 0.31401192297565106
# 0.3140101709180486
# 0.31400841892758063
# 0.31400666700424396
# 0.3140049151480352
# 0.3140031633589512
# 0.3140014116369886
# 0.31399965998214413
# 0.31399790839441455
# 0.31399615687379656
# 0.3139944054202869
# 0.3139926540338822
# 0.3139909027145793
# 0.3139891514623749
# 0.3139874002772656
# 0.31398564915924837
# 0.3139838981083197
# 0.3139821471244765
# 0.31398039620771523
# 0.31397864535803294
# 0.31397689457542616
# 0.31397514385989156
# 0.31397339321142603
# 0.3139716426300262
# 0.3139698921156889
# 0.3139681416684106
# 0.3139663912881883
# 0.31396464097501864
# 0.31396289072889827
# ...

# %%
evaluate(X, y_true)
# Out:
# accuracy:  84.46666666666667
